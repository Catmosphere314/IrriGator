# %% [markdown]
# # IrriGator — Full End-to-End Pipeline
#
# Central notebook covering **every block** from raw data to irrigation recommendation.
#
# | Block | What | Data source | Run frequency |
# |-------|------|-------------|---------------|
# | 0 | Data ingestion | ERA5-Land (France-wide), COMEPHORE, Sentinel-2, soil, DEM | Once (historical archive) |
# | 1 | Static layers | EU-SoilHydroGrids, IGN DEM | Once per parcel |
# | 2 | Atmospheric forcing | ERA5-Land daily → parcel extraction | Once (cache), then per parcel |
# | 3+4 | Simulation | Water balance + crop growth ACQUACROP | Daily |
# | 5a | Short-term forecast | AROME (0-48h) + IFS ENS (0-15d) → ensemble | Daily |
# | 5b | Seasonal outlook | SEAS5 → PCA analog → ensemble water balance | Monthly |
# | 6 | Decision | Ensemble stress → irrigation recommendation | Daily |
#
# **Architecture change:** ERA5-Land is now downloaded once for all of metropolitan
# France (41°N–51.5°N, 6°W–10°E). Any new parcel is served from this cache
# without additional API calls. AROME and IFS ENS already work the same way.

# %% [markdown]
# ---
# ## Configuration — set your "today" and paths here

# %%
import logging
import os
from datetime import date
from pathlib import Path
from datetime import timedelta

# === EDIT THESE ===
REPO_ROOT = os.path.dirname(os.getcwd())  # adjust if needed
os.chdir(REPO_ROOT)

range_years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025,2026]


TODAY = date.today()
TODAYS = [date(year, TODAY.month, TODAY.day) for year in range_years]  # same day for each year

SIMULATION_START = date(2026, 1, 1)  # start of the growing season simulation
SIMULATION_STARTS = [date(year, SIMULATION_START.month, SIMULATION_START.day) for year in range_years]  # same day for each year

LAST_IRRIGATION = None              # date of last irrigation, or None for rainfed
RUN_SEAS5 = False                   # set True to include seasonal outlook (slow)
SHIFT = 0                           # set to 1 if you want UTC+1

# Paths — all relative to REPO_ROOT
RAW_DIR = Path("data/raw")                # ERA5-Land, SEAS5, IFS ENS raw downloads
PROCESSED_DIR = Path("data/processed")     # daily aggregates, cached results
STATIC_DIR = Path("data/static")           # static ERA5-Land data (soil, land cover, etc.)

# Parcel and region configs (region still needed for static layers)
REGION_CONFIG = "configs/dordogne.yaml"
PARCEL_CONFIG = [f"configs/parcels/billac_{year}.yaml" for year in range_years]
PARCEL_CONFIG2 = [f"configs/parcels/guide_{year}.yaml" for year in range_years]


CROP_PARAMS_PATH = "configs/crop_parameters.yaml"
MODEL_PARAMS_PATH = "configs/model_parameters.yaml"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(name)s] %(levelname)s: %(message)s",
    datefmt="%H:%M:%S",
)

print(f"Repo root: {REPO_ROOT}")
print(f"Today:     {TODAY}")
print(f"Raw dir:   {RAW_DIR}")
print(f"Processed: {PROCESSED_DIR}")
# Out:
# Repo root: /home/mbaldacchino/code/IrriGator
# Today:     2026-09-02
# Raw dir:   data/raw
# Processed: data/processed

# %% [markdown]
# ---
# ## Block 0 — Data Ingestion
#
# Run these cells **once** to download and cache the historical archive.
# Skip if data is already on disk.
#
# ERA5-Land is downloaded for all of France — not per region. One download
# covers any parcel in metropolitan France.

# %%
from irrigator.config import load_region_config, load_parcel_config

cfg = load_region_config(REGION_CONFIG)
parcel = [load_parcel_config(p) for p in PARCEL_CONFIG]
parcel2 = [load_parcel_config(p) for p in PARCEL_CONFIG2]


print(f"Region: {cfg.name} (dept {cfg.code_departement})")
print(f"Parcel: {parcel[0].name} ({parcel[0].id})")
print(f"Crop:   {parcel[0].crop.get('type')} — planting {parcel[0].crop.get('planting_date')}")
# Out:
# Region: Dordogne (dept 24)
# Parcel: Parcelle Billac - SEP des Pouyades (billac_001)
# Crop:   grain_maize — planting 2013-04-14

# %%
# --- ERA5-Land download (skip if already done) ---
# France-wide, no per-region dependency
# from irrigator.ingestion.cds_client import fetch_era5_land_range
# fetch_era5_land_range(date(2014, 1, 1), date.today(), raw_dir=RAW_DIR, overwrite=False, force_cds_refresh=True)

# %%
# --- Build static layers (skip if already done) ---
# These still use RegionConfig because they depend on the regional DEM/soil grids
# from irrigator.ingestion.esdac_loader import load_soil_hydro, save_soil_hydro
# from irrigator.ingestion.ign_loader import load_terrain, save_terrain
# from irrigator.ingestion.grid import build_grid
#
# grid = build_grid(cfg)
# soil_grid = load_soil_hydro(cfg, grid)
# save_soil_hydro(soil_grid, cfg.processed_dir / "static")
# terrain_grid = load_terrain(cfg, grid)
# save_terrain(terrain_grid, cfg.processed_dir / "static")

# %% [markdown]
# ---
# ## Block 1 — Static Layers (parcel-level)
#
# Extract soil and terrain at the parcel location. Run once per parcel, cache.

# %%
from irrigator.static_layers.soil import get_soil_profile
from irrigator.static_layers.terrain import get_terrain_params, get_era5_elevation

soil = [get_soil_profile(cfg, parcel[0])] * len(parcel)
soil2 = [get_soil_profile(cfg, parcel2[0])] * len(parcel2)

terrain = [get_terrain_params(cfg, parcel[0])] * len(parcel)
era5_elevation = get_era5_elevation(cfg, parcel[0])
for idx,p in enumerate(parcel):
    terrain[idx].era5_elevation_m = era5_elevation
    

terrain2 = [get_terrain_params(cfg, parcel2[0])] * len(parcel2)
era5_elevation2 = get_era5_elevation(cfg, parcel2[0])
for idx,p in enumerate(parcel2):
    terrain2[idx].era5_elevation_m = era5_elevation2


print(f"Soil AWC:  {soil[0].total_awc_mm:.0f} mm (source: {soil[0].source})")
print(f"Elevation: {terrain[0].elevation_m:.0f} m (ERA5 cell: {terrain[0].era5_elevation_m:.0f} m)")
print(f"Slope:     {terrain[0].slope_deg:.1f}°")
# Out:
# 13:38:46 [numexpr.utils] INFO: Note: NumExpr detected 22 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 13:38:46 [numexpr.utils] INFO: NumExpr defaulting to 16 threads.
# 13:38:49 [irrigator.static_layers.soil] INFO: Parcel billac_001: using EU-SoilHydroGrids — AWC=235 mm, FC=[0.362, 0.342, 0.340, 0.337, 0.320, 0.319]
# 13:38:49 [irrigator.static_layers.soil] INFO: Parcel guide_001: using EU-SoilHydroGrids — AWC=249 mm, FC=[0.360, 0.350, 0.340, 0.340, 0.331, 0.317]
# 13:38:49 [irrigator.static_layers.terrain] INFO: Parcel billac_001 terrain: elev=140 m, slope=3.1°, aspect=89°
# 13:38:49 [irrigator.ingestion.cds_client] INFO: Opening 200 ERA5-Land files with dask
# 13:38:59 [irrigator.static_layers.terrain] INFO: Parcel guide_001 terrain: elev=141 m, slope=3.3°, aspect=282°
# 13:38:59 [irrigator.ingestion.cds_client] INFO: Opening 200 ERA5-Land files with dask
# Soil AWC:  235 mm (source: eu_soilhydrogrids)
# Elevation: 140 m (ERA5 cell: 145 m)
# Slope:     3.1°

# %%
from irrigator.water_balance.plot_aquacrop_soils import compare_soils
import matplotlib.pyplot as plt
from irrigator.water_balance.aquacrop_adapter import soil_to_aquacrop

fig, summary = compare_soils(
    soil_a=soil_to_aquacrop(soil[0]).profile,
    soil_b=soil_to_aquacrop(soil2[0]).profile,
    labels=("Billac", "Guide"),
    comparison_depth=1.5,  # for example, maize root-zone depth
)

display(summary.round(1))

fig.savefig(
    "soil_comparison.png",
    dpi=200,
    bbox_inches="tight",
)

plt.show()
# Out:
# 11:32:05 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# 11:32:05 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
#         profile_depth_m  comparison_depth_m  TAW_mm  drainable_water_mm  \
# parcel
# Billac              2.0                 1.5   181.9               164.9
# Guide               2.0                 1.5   195.0               170.0
#
#         saturation_storage_mm  median_Ksat_mm_day
# parcel
# Billac                  657.0               340.8
# Guide                   667.0               340.8

# %% [markdown]
# ---
# ## Block 2 — Atmospheric Forcing
#
# Process ERA5-Land hourly → daily (once for all of France), then extract at parcel.
#
# The daily cache is grid-agnostic: any parcel in France can extract its
# forcing from the same file via `extract_parcel_forcing()`.

# %%
from irrigator.atmospheric.era5_processor import load_daily, process_era5_to_daily, save_daily
from irrigator.atmospheric.forcing import extract_parcel_forcing

# First time: process hourly → daily (slow, do once)
from irrigator.ingestion.cds_client import open_era5_land
# for year in range_years:
#     print(year)
#     era5_hourly = open_era5_land(raw_dir=RAW_DIR, start=date(year, 1, 1), end=date(year, 12, 31))
#     era5_daily = process_era5_to_daily(era5_hourly, shift_utc=SHIFT)
#     save_daily(era5_daily, processed_dir=PROCESSED_DIR)

forcing = []
forcing2 = []

for idx,year in enumerate(range_years):
    # # After that: just load cached
    era5_daily = load_daily(processed_dir=PROCESSED_DIR, year=year)
    forcing.append(extract_parcel_forcing(era5_daily, parcel[idx], terrain[idx]))
    forcing2.append(extract_parcel_forcing(era5_daily, parcel2[idx], terrain2[idx]))
    era5_daily.close()


print(f"Forcing: {forcing[0].n_days} days")
print(f"T range: [{forcing[0].t_min.min():.1f}, {forcing[0].t_max.max():.1f}] °C")
print(f"Total precip: {forcing[0].precip_mm.sum():.0f} mm")
# Out:
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-6.4, 35.9]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-6.5, 35.8]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-3.0, 33.9]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-3.1, 33.9]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:24 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-4.1, 36.3]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-4.2, 36.3]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 366 days, T=[-2.7, 35.5]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 366 days, T=[-2.8, 35.4]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-4.9, 35.1]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:25 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-4.9, 35.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-4.9, 35.1]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-5.0, 35.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-2.9, 38.5]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:26 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-2.9, 38.4]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 366 days, T=[-1.3, 37.6]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 366 days, T=[-1.3, 37.6]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-3.2, 32.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-3.2, 32.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-5.0, 37.5]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:27 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-5.0, 37.4]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-3.7, 38.9]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-3.7, 38.9]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 366 days, T=[-3.4, 36.4]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 366 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 366 days, T=[-3.5, 36.3]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 365 days, T=[-4.0, 39.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 365 days from ERA5-Land at grid cell (0, 45)
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:28 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 365 days, T=[-4.0, 39.0]°C, total precip=nan mm, mean Rs=nan MJ/m²/day
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 223 days from ERA5-Land at grid cell (0, 45)
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 223 days, T=[-5.1, 39.8]°C, total precip=522 mm, mean Rs=17.1 MJ/m²/day
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Parcel guide_001: extracted 223 days from ERA5-Land at grid cell (0, 45)
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=3 m, ΔT=-0.02°C
# 13:24:29 [irrigator.atmospheric.forcing] INFO: Parcel guide_001 forcing: 223 days, T=[-5.2, 39.7]°C, total precip=522 mm, mean Rs=17.0 MJ/m²/day
# Forcing: 365 days
# T range: [-6.4, 35.9] °C
# Total precip: nan mm

# %% [markdown]
# ---
# ## Blocks 3+4 — Historical Simulation up to TODAY
#
# Coupled crop growth + water balance from `SIMULATION_START` to `TODAY`.
# The final state is the starting point for the forecast.

# %%
from irrigator.water_balance.aquacrop_adapter import run_aquacrop
import pandas as pd


historical_results = {"Billac": {}, "Guide": {}}

for idx,year in enumerate(range_years):
    print(f"Running AquaCrop for {year}...")
    historical_forcing = forcing[idx].slice(SIMULATION_STARTS[idx], TODAYS[idx])
    historical_forcing2 = forcing2[idx].slice(SIMULATION_STARTS[idx], TODAYS[idx])

    LAST_ERA5_DAY = pd.to_datetime(historical_forcing.dates[-1]).date()

    hist_run = run_aquacrop(
        forcing=historical_forcing,
        parcel=parcel[idx],
        terrain=terrain[idx],
        soil_profile=soil[idx],
        sim_start=SIMULATION_STARTS[idx],
        sim_end=LAST_ERA5_DAY,
    )

    # Daily stress metrics (Ks equivalent, canopy cover, biomass, etc.)
    stress = hist_run.daily_stress
    # Drop rows past your actual data
    valid = stress[stress["dap"] > 0].iloc[:-1]  # drop AquaCrop's terminal zero-row
    last = valid.iloc[-1]

    hist_run2 = run_aquacrop(
        forcing=historical_forcing2,
        parcel=parcel2[idx],
        terrain=terrain2[idx],
        soil_profile=soil2[idx],
        sim_start=SIMULATION_STARTS[idx],
        sim_end=LAST_ERA5_DAY,
    )
    historical_results["Billac"][year] = hist_run
    historical_results["Guide"][year] = hist_run2
# Out:
# 12:03:46 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.40m depth, 24 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# Running AquaCrop for 2013...
# MaizeGDD
# 12:03:46 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2013-01-01 → 2013-08-11 (223 days), GDD=1276, CC=0.96, biomass=2007 kg/ha
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:03:46 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.40m depth, 24 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# MaizeGDD
# 12:03:47 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2013-01-01 → 2013-08-11 (223 days), GDD=1289, CC=0.96, biomass=2074 kg/ha
# 12:03:47 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.40m depth, 24 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# Running AquaCrop for 2014...
# MaizeGDD
# 12:03:48 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2014-01-01 → 2014-08-11 (223 days), GDD=1313, CC=0.96, biomass=2181 kg/ha
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:03:48 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.40m depth, 24 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# MaizeGDD
# 12:03:49 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 
[irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2026-01-01 → 2026-08-04 (216 days), GDD=1649, CC=0.94, biomass=2447 kg/ha
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.40m depth, 24 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# MaizeGDD
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2026-01-01 → 2026-08-04 (216 days), GDD=1715, CC=0.91, biomass=2589 kg/ha

# %%
hist_run.crop_growth
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hist_run.crop_growth
#
# NameError: name 'hist_run' is not defined

# %%
hist_run.crop_growth.plot()
# Out:
# <Axes: >

# %%
hist_run.daily_stress.plot()
# Out:
# <Axes: >

# %%
hist_run.final_results
# Out:
#    Season crop Type Harvest Date (YYYY/MM/DD)  Harvest Date (Step)  \
# 0       0  MaizeGDD                2025-09-02                  243
#
#    Dry yield (tonne/ha)  Fresh yield (tonne/ha)  Yield potential (tonne/ha)  \
# 0             13.754883               15.283204                   13.843459
#
#    Seasonal irrigation (mm)
# 0                     415.0

# %%
hist_run3.final_results
# Out:
#    Season crop Type Harvest Date (YYYY/MM/DD)  Harvest Date (Step)  \
# 0       0  MaizeGDD                2025-07-25                  204
#
#    Dry yield (tonne/ha)  Fresh yield (tonne/ha)  Yield potential (tonne/ha)  \
# 0              1.213158                1.347953                    1.788988
#
#    Seasonal irrigation (mm)
# 0                         0

# %%
import pandas as pd
import matplotlib.pyplot as plt

from irrigator.water_balance.plot_aquacrop_summary import (
    plot_aquacrop_season,
    summarize_aquacrop_seasons,
)
from irrigator.water_balance.aquacrop_adapter import soil_to_aquacrop

sim_start = "2026-01-01"

runs = {
    "Billac irrigated": {
        "parcel": "Billac",
        "scenario": "current",
        "crop_growth": hist_run.crop_growth,
        "water_flux": hist_run.water_flux,
        "daily_stress": hist_run.daily_stress,
        "soil": soil_to_aquacrop(soil).profile,
        "sim_start": sim_start,
        "season": 0,
    },
    "Billac 2025": {
        "parcel": "Billac",
        "scenario": "past",
        "crop_growth": hist_run3.crop_growth,
        "water_flux": hist_run3.water_flux,
        "daily_stress": hist_run3.daily_stress,
        "soil": soil_to_aquacrop(soil3).profile,
        "sim_start": sim_start,
        "season": 0,
    },
    "Guide irrigated": {
        "parcel": "Guide",
        "scenario": "current",
        "crop_growth": hist_run2.crop_growth,
        "water_flux": hist_run2.water_flux,
        "daily_stress": hist_run2.daily_stress,
        "soil": soil_to_aquacrop(soil2).profile,
        "sim_start": sim_start,
        "season": 0,
    },
    "Guide 2025": {
        "parcel": "Guide",
        "scenario": "past",
        "crop_growth": hist_run4.crop_growth,
        "water_flux": hist_run4.water_flux,
        "daily_stress": hist_run4.daily_stress,
        "soil": soil_to_aquacrop(soil4).profile,
        "sim_start": sim_start,
        "season": 0,
    },
}

fig, prepared = plot_aquacrop_season(
    runs,
    figsize=(16, 14),
)

# fig.savefig(
#     "aquacrop_2025_scenarios.png",
#     dpi=200,
#     bbox_inches="tight",
# )

plt.show()


series_metadata = {
    name: {
        "parcel": data.attrs["parcel"],
        "scenario": data.attrs["scenario"],
    }
    for name, data in prepared.items()
}

summary = summarize_aquacrop_seasons(
    prepared,
    series_metadata,
)

display(
    summary[
        [
            "parcel",
            "scenario",
            "final_dry_yield_t_ha",
            "potential_dry_yield_t_ha",
            "irrigation_mm",
            "transpiration_mm",
            "deep_percolation_mm",
            "transpiration_stress_days",
            "minimum_tr_over_trpot",
            "maximum_root_zone_depletion_fraction",
        ]
    ].round(2)
)
# Out:
# 12:52:11 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# 12:52:12 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# 12:52:12 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# 12:52:12 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
#    parcel scenario  final_dry_yield_t_ha  potential_dry_yield_t_ha  \
# 0  Billac  current                  6.35                      6.42
# 1  Billac     past                  2.96                      2.98
# 2   Guide  current                  7.30                      7.42
# 3   Guide     past                  4.01                      4.03
#
#    irrigation_mm  transpiration_mm  deep_percolation_mm  \
# 0          280.0            388.51                30.88
# 1          280.0            307.73                45.45
# 2          340.0            405.87                27.41
# 3          340.0            328.66                89.43
#
#    transpiration_stress_days  minimum_tr_over_trpot  \
# 0                          0                    1.0
# 1                          0                    1.0
# 2                          0                    1.0
# 3                          0                    1.0
#
#    maximum_root_zone_depletion_fraction
# 0                                  0.54
# 1                                  0.35
# 2                                  0.41
# 3                                  0.40

# %%
summary[
        [
            "parcel",
            "scenario",
            "final_dry_yield_t_ha",
            "potential_dry_yield_t_ha",
            "irrigation_mm",
            "transpiration_mm",
            "deep_percolation_mm",
            "transpiration_stress_days",
            "minimum_tr_over_trpot",
            "maximum_root_zone_depletion_fraction",
        ]
    ].round(2).to_csv("/home/mbaldacchino/data/summary.csv")

# %%
diagnostics = pd.DataFrame(
    {
        name: {
            "cumulative_deep_perc_mm": data["deep_perc_mm"].sum(),
            "maximum_daily_deep_perc_mm": data["deep_perc_mm"].max(),
            "days_with_deep_perc": (data["deep_perc_mm"] > 0.01).sum(),
            "mean_when_active_mm_day": data.loc[
                data["deep_perc_mm"] > 0.01,
                "deep_perc_mm",
            ].mean(),
            "days_above_field_capacity": (data["available_water_fraction"] > 1).sum(),
        }
        for name, data in prepared.items()
    }
).T

print(diagnostics.round(2))
# Out:
#         cumulative_deep_perc_mm  maximum_daily_deep_perc_mm  \
# Billac                    52.05                        1.00
# Guide                    154.31                       10.88
#
#         days_with_deep_perc  mean_when_active_mm_day  \
# Billac                118.0                     0.44
# Guide                  94.0                     1.64
#
#         days_above_field_capacity
# Billac                       42.0
# Guide                        71.0

# %% [markdown]
# ### Past summary

# %%
import matplotlib.pyplot as plt

from irrigator.water_balance.aquacrop_adapter import soil_to_aquacrop
from irrigator.water_balance.plot_aquacrop_historical import (
    make_run_config,
    plot_aquacrop_historical_benchmark,
    compact_benchmark_table,
)

current_runs = {
    "Billac 2026": make_run_config(
        hist_run,
        parcel="Billac",
        soil=soil_to_aquacrop(soil[-1]).profile,
        sim_start="2026-01-01",
        year=2026,
        scenario="current",
    ),
    "Guide 2026": make_run_config(
        hist_run2,
        parcel="Guide",
        soil=soil_to_aquacrop(soil2[-1]).profile,
        sim_start="2026-01-01",
        year=2026,
        scenario="current",
    ),
}

historical_runs = {}

for idx,year in enumerate(range(2013, 2026)):
    billac_run = historical_results["Billac"][year]
    guide_run = historical_results["Guide"][year]

    historical_runs[f"Billac {year}"] = make_run_config(
        billac_run,
        parcel="Billac",
        soil=soil_to_aquacrop(soil[idx]).profile,
        sim_start=f"{year}-01-01",
        year=year,
        scenario="historical",
    )

    historical_runs[f"Guide {year}"] = make_run_config(
        guide_run,
        parcel="Guide",
        soil=soil_to_aquacrop(soil2[idx]).profile,
        sim_start=f"{year}-01-01",
        year=year,
        scenario="historical",
    )


fig, benchmark = plot_aquacrop_historical_benchmark(
    current_runs=current_runs,
    historical_runs=historical_runs,
    figsize=(16, 14),
    # min_year_fraction=0.75,
    # stress_threshold=0.99,
    title="2026 season compared with 2006–2025",
    threshold_similarity_tolerance=0.02,
    show_stomatal_zone=True,
)

fig.savefig(
    "aquacrop_2026_historical_benchmark.png",
    dpi=200,
    bbox_inches="tight",
)

plt.show()


summary = compact_benchmark_table(benchmark.metric_benchmark)

display(summary.round(2))
# Out:
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:07 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:08 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:09 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# 12:04:10 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.00m depth, 20 x 0.10m compartments, FC range 0.317-0.355, WP range 0.171-0.210, Ksat range 42-662 mm/day
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:543: RuntimeWarning: invalid value encountered in divide
#   wf["Tr"].values[:n] / wf["TrPot"].values[:n],
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/plot_aquacrop_historical.py:543: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   result.loc[~result["active"], crop_state_columns] = np.nan
#     parcel                                metric  \
# 0   Billac                  current_biomass_t_ha
# 1   Billac                current_dry_yield_t_ha
# 2   Billac                   deep_percolation_mm
# 3   Billac                         final_gdd_cum
# 4   Billac                         irrigation_mm
# 5   Billac  maximum_root_zone_depletion_fraction
# 6   Billac            minimum_stomatal_margin_mm
# 7   Billac                      precipitation_mm
# 8   Billac      stomatal_threshold_crossing_days
# 9   Billac                      transpiration_mm
# 10  Billac             transpiration_stress_days
# 11   Guide                  current_biomass_t_ha
# 12   Guide                current_dry_yield_t_ha
# 13   Guide                   deep_percolation_mm
# 14   Guide                         final_gdd_cum
# 15   Guide                         irrigation_mm
# 16   Guide  maximum_root_zone_depletion_fraction
# 17   Guide            minimum_stomatal_margin_mm
# 18   Guide                      precipitation_mm
# 19   Guide      stomatal_threshold_crossing_days
# 20   Guide                      transpiration_mm
# 21   Guide             transpiration_stress_days
#
#                                 label    unit  current   median  \
# 0          Biomass at comparison date    t/ha    24.77    22.42
# 1        Dry yield at comparison date    t/ha     8.01     3.12
# 2         Cumulative deep percolation      mm    30.89    62.77
# 3                      Cumulative GDD  °C·day  1667.67  1378.18
# 4               Cumulative irrigation      mm   280.00   280.00
# 5         Maximum root-zone depletion  Dr/TAW     0.54     0.44
# 6   Minimum margin to stomatal stress      mm    12.70    16.70
# 7            Cumulative precipitation      mm   194.92   258.86
# 8   Days beyond stomatal-stress onset    days     0.00     0.00
# 9            Cumulative transpiration      mm   409.20   289.33
# 10          Transpiration-stress days    days     0.00     0.00
# 11         Biomass at comparison date    t/ha    26.17    23.58
# 12       Dry yield at comparison date    t/ha     9.16     3.83
# 13        Cumulative deep percolation      mm    27.41   187.40
# 14                     Cumulative GDD  °C·day  1733.53  1426.51
# 15              Cumulative irrigation      mm   380.00   380.00
# 16        Maximum root-zone depletion  Dr/TAW     0.41     0.39
# 17  Minimum margin to stomatal stress      mm    17.60    19.26
# 18           Cumulative precipitation      mm   198.96   281.84
# 19  Days beyond stomatal-stress onset    days     0.00     0.00
# 20           Cumulative transpiration      mm   425.42   302.20
# 21          Transpiration-stress days    days     0.00     0.00
#
#    historical_q25_q75  percentile  n_historical
# 0         20.20–23.27       92.31            13
# 1           1.04–3.93      100.00            13
# 2         45.46–75.01        0.00            13
# 3     1210.37–1395.50      100.00            13
# 4       280.00–280.00       50.00            13
# 5           0.39–0.49      100.00            13
# 6         13.11–19.50       15.38            13
# 7       235.89–292.42        7.69            13
# 8           0.00–0.00       50.00            13
# 9       244.97–323.71      100.00            13
# 10          0.00–6.00       30.77            13
# 11        21.83–24.82      100.00            13
# 12          1.93–5.40      100.00            13
# 13      166.51–223.74        0.00            13
# 14    1270.44–1449.13      100.00            13
# 15      380.00–380.00       50.00            13
# 16          0.34–0.43       69.23            13
# 17        15.79–24.25       46.15            13
# 18      267.63–294.50        7.69            13
# 19          0.00–0.00       50.00            13
# 20      251.37–336.51      100.00            13
# 21          0.00–0.00       50.00            13

# %% [markdown]
# ---
# ## Block 5a — Operational forecast with AquaCrop
#
# With AquaCrop, forecasting means rerunning the full simulation from Jan 1
# with different future forcings appended. This preserves the stress-growth
# coupling — a crop that was stressed in June will have smaller canopy in
# July, which reduces water demand.
#
# - **AROME** (0-48h): one AquaCrop run with deterministic forecast appended
# - **IFS ENS** (0-15d): 50 AquaCrop runs, one per ensemble member
# - **Blended report**: AROME days 0-2 (high resolution), IFS ENS days 3+ (ensemble spread)

# %%
# --- Cell: Extract current state from historical AquaCrop run ---
# (put this right after Block 3-4)

from irrigator.water_balance.aquacrop_adapter import (
    aquacrop_to_current_state,
    build_blended_stress_report,
    run_ensemble_aquacrop,
)

current_state = aquacrop_to_current_state(hist_run, soil, LAST_ERA5_DAY)

print(f"Current state at {LAST_ERA5_DAY}:")
print(f"  Depletion:  {current_state.depletion:.0f} mm")
print(f"  TAW:        {current_state.taw:.0f} mm")
print(f"  RAW:        {current_state.raw:.0f} mm")
print(f"  Ks:         {current_state.stress_coeff:.3f}")
print(f"  Root depth: {current_state.z_root:.2f} m")
print(f"  GDD:        {current_state.gdd:.0f}")
print(f"  Stage:      {current_state.crop_stage}")
# Out:
# Current state at 2026-06-30:
#   Depletion:  149 mm
#   TAW:        192 mm
#   RAW:        117 mm
#   Ks:         0.794
#   Root depth: 1.63 m
#   GDD:        992
#   Stage:      midseason

# %%
# --- Cell: Build historical forcing for forecast branching ---

from irrigator.atmospheric.forcing import extract_parcel_forcing
from irrigator.forecasts.arome_processing import load_arome_daily_cache
from datetime import timedelta
import numpy as np

# ERA5-Land historical
era5_last = pd.Timestamp(era5_daily.valid_time.values[-1]).date()
era5_forcing = forcing.slice(SIMULATION_START, era5_last)

# AROME gap fill (era5_last → yesterday)
gap_start = era5_last + timedelta(days=1)
gap_end = TODAY - timedelta(days=1)

if gap_start <= gap_end:
    arome_gap = load_arome_daily_cache(gap_start, gap_end, mode="static")
    gap_forcing = extract_parcel_forcing(arome_gap, parcel, terrain)
    historical_forcing = era5_forcing.concat(gap_forcing)
    print(f"Gap filled: {gap_forcing.n_days} days ({gap_start} → {gap_end})")
else:
    historical_forcing = era5_forcing
    print("No gap to fill")

print(f"Historical forcing: {historical_forcing.n_days} days")

# fake_date = [
#     np.datetime64(date(2026, 6, 24), "ns"),
#     np.datetime64(date(2026, 6, 25), "ns"),
#     np.datetime64(date(2026, 6, 26), "ns"),
# ]
# fake_t_min = [20, 20, 20]
# fake_t_max = [30, 30, 30]
# fake_t_mean = [25, 25, 25]
# fake_dewpoint = [14, 14, 14]
# fake_windspeed = [3, 3, 3]
# fake_press = [101, 101, 101]
# fake_rs = [10, 10, 10]
# fake_precip = [0, 0, 0]
# historical_forcing.dates = np.insert(historical_forcing.dates, 174, fake_date)
# historical_forcing.dewpoint = np.insert(historical_forcing.dewpoint, 174, fake_dewpoint)
# historical_forcing.t_max = np.insert(historical_forcing.t_max, 174, fake_t_max)
# historical_forcing.t_mean = np.insert(historical_forcing.t_mean, 174, fake_t_mean)
# historical_forcing.t_min = np.insert(historical_forcing.t_min, 174, fake_t_min)
# historical_forcing.precip_mm = np.insert(historical_forcing.precip_mm, 174, fake_precip)
# historical_forcing.pressure_kpa = np.insert(historical_forcing.pressure_kpa, 174, fake_press)
# historical_forcing.wind_speed_2m = np.insert(historical_forcing.wind_speed_2m, 174, fake_windspeed)
# historical_forcing.rs_mj = np.insert(historical_forcing.rs_mj, 174, fake_rs)
# Out:
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 7 days from ERA5-Land at grid cell (0, 45)
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 7 days, T=[13.8, 38.4]°C, total precip=0 mm, mean Rs=29.0 MJ/m²/day
# Gap filled: 7 days (2026-07-01 → 2026-07-07)
# Historical forcing: 188 days

# %%
# --- Cell: AROME 48h deterministic forecast ---

arome_today = load_arome_daily_cache(TODAY , TODAY + timedelta(days=1), mode="forecast")
arome_forcing_48h = extract_parcel_forcing(arome_today, parcel, terrain)
# Fix date alignment if needed
arome_forcing_48h.dates = arome_forcing_48h.dates #- np.timedelta64(1, "D")

print(f"AROME forecast: {arome_forcing_48h.n_days} days")
print(f"  T range: [{arome_forcing_48h.t_min.min():.1f}, {arome_forcing_48h.t_max.max():.1f}] °C")

# Run full AquaCrop: historical + AROME 48h
arome_full_forcing = historical_forcing.concat(arome_forcing_48h)


arome_run = run_aquacrop(
    forcing=arome_full_forcing,
    parcel=parcel,
    terrain=terrain,
    soil_profile=soil,
    sim_start=SIMULATION_START,
    sim_end=pd.Timestamp(arome_full_forcing.dates[-1]).date(),
)

# Quick check: AROME Ks for the forecast days
arome_stress = arome_run.daily_stress
print(f"AROME last 3 days Ks: {arome_stress.ks.iloc[-4:-1].values}")
# Out:
# 16:41:59 [arome] WARNING: 1 missing days: [datetime.date(2026, 7, 9)]
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 2 days from ERA5-Land at grid cell (0, 45)
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:41:59 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 2 days, T=[19.1, 39.0]°C, total precip=0 mm, mean Rs=29.1 MJ/m²/day
# 16:42:00 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.30m depth, 23 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# AROME forecast: 2 days
#   T range: [19.1, 39.0] °C
# MaizeGDD
# 16:42:00 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop run: 2026-01-01 → 2026-07-09 (190 days), GDD=1152, CC=0.77, biomass=1331 kg/ha
# AROME last 3 days Ks: [0.44421646 0.42931603 0.45583433]

# %%
# --- Cell: IFS ENS ensemble ---

from irrigator.ingestion.ifs_ens_client import load_ifs_daily

ifs_daily = load_ifs_daily(processed_dir=PROCESSED_DIR)

# Extract per-member forcing at parcel level
member_forcings = {}
for m in ifs_daily.number.values:
    member_ds = ifs_daily.sel(number=m)
    forcing_m = extract_parcel_forcing(member_ds, parcel, terrain)
    # Filter to remove arome overlap + limit due to shift utc + 1
    member_forcings[int(m)] = forcing_m.slice(start=TODAY + timedelta(2), end=TODAY + timedelta(14)) # hsould be 14

print(
    f"IFS ENS: {len(member_forcings)} members, {member_forcings[next(iter(member_forcings))].n_days} days"
)

# Run AquaCrop for each member (full simulation: Jan 1 → forecast end)
# Each member gets historical + its own forecast forcing
ensemble_stats = run_ensemble_aquacrop(
    historical_forcing=historical_forcing,
    arome_forcing=arome_forcing_48h,
    member_forcings=member_forcings,
    parcel=parcel,
    terrain=terrain,
    soil_profile=soil,
    sim_start=SIMULATION_START,
    today=TODAY - timedelta(days=1),
)

print(f"Ensemble stats: {len(ensemble_stats)} days")
for s in ensemble_stats[:3]:
    print(
        f"  Day {s.day_offset}: Ks={s.ks_mean:.3f} (p25={s.ks_p25:.3f}, p75={s.ks_p75:.3f}), "
        f"stress={s.n_members_stressed}/{s.n_members_total}"
    )

# pd.Timestamp(arome_full_forcing.dates[-2]).date()
# Out:
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.1, 37.4]°C, total precip=30 mm, mean Rs=23.1 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[14.5, 38.1]°C, total precip=40 mm, mean Rs=21.2 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.2, 38.0]°C, total precip=17 mm, mean Rs=23.2 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.9, 37.4]°C, total precip=22 mm, mean Rs=22.9 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.2, 37.4]°C, total precip=13 mm, mean Rs=24.6 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.4, 36.2]°C, total precip=18 mm, mean Rs=25.1 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.6, 38.0]°C, total precip=11 mm, mean Rs=23.6 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.5, 39.0]°C, total precip=9 mm, mean Rs=20.6 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.1, 37.3]°C, total precip=15 mm, mean Rs=23.8 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.1, 38.9]°C, total precip=5 mm, mean Rs=25.1 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.5, 38.0]°C, total precip=5 mm, mean Rs=24.2 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.3, 36.9]°C, total precip=6 mm, mean Rs=23.6 MJ/m²/day
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:00 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.1, 37.4]°C, total precip=16 mm, mean Rs=24.6 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.8, 36.8]°C, total precip=44 mm, mean Rs=22.3 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.9, 38.0]°C, total precip=11 mm, mean Rs=24.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.3, 37.6]°C, total precip=25 mm, mean Rs=22.9 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.4, 39.5]°C, total precip=13 mm, mean Rs=24.3 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.6, 38.1]°C, total precip=15 mm, mean Rs=23.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.0, 37.7]°C, total precip=20 mm, mean Rs=23.8 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.4, 38.3]°C, total precip=13 mm, mean Rs=23.0 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.8, 37.9]°C, total precip=25 mm, mean Rs=25.4 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[19.4, 38.3]°C, total precip=3 mm, mean Rs=25.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[19.7, 37.2]°C, total precip=20 mm, mean Rs=24.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[19.2, 37.3]°C, total precip=11 mm, mean Rs=24.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.8, 37.4]°C, total precip=28 mm, mean Rs=22.7 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.4, 39.3]°C, total precip=10 mm, mean Rs=24.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[20.4, 39.0]°C, total precip=4 mm, mean Rs=25.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.9, 37.1]°C, total precip=6 mm, mean Rs=25.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[19.4, 41.9]°C, total precip=6 mm, mean Rs=25.7 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[20.6, 37.3]°C, total precip=4 mm, mean Rs=25.7 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.1, 37.8]°C, total precip=30 mm, mean Rs=24.1 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.1, 36.4]°C, total precip=48 mm, mean Rs=23.4 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[14.1, 38.6]°C, total precip=22 mm, mean Rs=22.3 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.2, 37.6]°C, total precip=17 mm, mean Rs=23.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.1, 37.0]°C, total precip=41 mm, mean Rs=23.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[15.8, 37.2]°C, total precip=59 mm, mean Rs=23.3 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.7, 36.5]°C, total precip=16 mm, mean Rs=24.9 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.3, 36.7]°C, total precip=26 mm, mean Rs=22.8 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.3, 37.0]°C, total precip=25 mm, mean Rs=22.6 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[13.6, 38.6]°C, total precip=25 mm, mean Rs=23.8 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.5, 37.3]°C, total precip=2 mm, mean Rs=25.9 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.1, 37.3]°C, total precip=19 mm, mean Rs=24.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.9, 37.5]°C, total precip=7 mm, mean Rs=25.4 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.6, 37.2]°C, total precip=12 mm, mean Rs=24.2 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[13.9, 37.5]°C, total precip=45 mm, mean Rs=22.8 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[17.2, 38.1]°C, total precip=10 mm, mean Rs=24.5 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[14.3, 36.8]°C, total precip=9 mm, mean Rs=24.6 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[18.4, 38.0]°C, total precip=17 mm, mean Rs=25.2 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.8, 36.8]°C, total precip=35 mm, mean Rs=22.4 MJ/m²/day
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001: extracted 16 days from ERA5-Land at grid cell (0, 45)
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Lapse correction: Δz=-5 m, ΔT=0.03°C
# 16:42:01 [irrigator.atmospheric.forcing] INFO: Parcel billac_001 forcing: 16 days, T=[16.6, 38.2]°C, total precip=21 mm, mean Rs=23.9 MJ/m²/day
# 16:42:01 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.30m depth, 23 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# 16:42:01 [irrigator.water_balance.aquacrop_adapter] INFO: Running AquaCrop ensemble: 50 members, 2026-01-01 → 2026-07-22 (weather pre-computed, 190 hist + 13 forecast days)
# IFS ENS: 50 members, 13 days
# MaizeGDD
# 16:42:20 [irrigator.water_balance.aquacrop_adapter] INFO: Ensemble complete: 13 days, 50 members, stress_days=12
# Ensemble stats: 13 days
#   Day 0: Ks=0.453 (p25=0.432, p75=0.471), stress=50/50
#   Day 1: Ks=0.444 (p25=0.429, p75=0.456), stress=50/50
#   Day 2: Ks=0.434 (p25=0.425, p75=0.454), stress=50/50

# %%
# --- Cell: Blend AROME + IFS ENS into stress report ---

stress_report = build_blended_stress_report(
    arome_run=arome_run,
    ensemble_stats=ensemble_stats,
    today=TODAY,
    arome_days=2,
)

print(
    f"Blended report: {len(stress_report.daily_stats)} days "
    f"({stress_report.arome_days} AROME + {stress_report.ens_days} IFS ENS)"
)
for d in stress_report.daily_stats[:5]:
    print(
        f"  {d.date.date() if hasattr(d.date, 'date') else d.date}: "
        f"[{d.source}] Ks={d.ks_median:.3f}, stress_prob={d.stress_probability:.0%}"
    )
# Out:
# Blended report: 15 days (2 AROME + 13 IFS ENS)
#   2026-07-08: [arome] Ks=0.456, stress_prob=100%
#   2026-07-09: [arome] Ks=0.431, stress_prob=100%
#   2026-07-10: [ifs_ens] Ks=0.444, stress_prob=100%
#   2026-07-11: [ifs_ens] Ks=0.444, stress_prob=100%
#   2026-07-12: [ifs_ens] Ks=0.429, stress_prob=100%

# %%
# --- Cell: Plot ensemble forecast (same as before, works unchanged) ---

import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 1, figsize=(14, 12), sharex=True)

dates = [d.date for d in stress_report.daily_stats]
sources = [d.source for d in stress_report.daily_stats]

# Ks with ensemble spread
ax = axes[0]
ks_med = [d.ks_median for d in stress_report.daily_stats]
ks_p25 = [d.ks_p25 for d in stress_report.daily_stats]
ks_p75 = [d.ks_p75 for d in stress_report.daily_stats]
ks_min = [d.ks_min for d in stress_report.daily_stats]
ks_max = [d.ks_max for d in stress_report.daily_stats]

ax.fill_between(dates, ks_min, ks_max, alpha=0.1, color="blue", label="min-max")
ax.fill_between(dates, ks_p25, ks_p75, alpha=0.7, color="blue", label="p25-p75")
ax.plot(dates, ks_med, "b-", lw=2, label="median")
ax.axhline(0.9, color="red", ls="--", alpha=0.5, label="Stress threshold")

for i, (d, src) in enumerate(zip(dates, sources)):
    if i == 0 or sources[i] != sources[i - 1]:
        ax.axvline(d, color="gray", ls=":", alpha=0.3)
        ax.text(d, 1.02, src, fontsize=8, rotation=45, transform=ax.get_xaxis_transform())

ax.set_ylabel("Ks (Tr/TrPot)")
ax.set_title("Crop stress — AquaCrop ensemble forecast")
ax.legend(loc="lower left")

# Stress probability
ax = axes[1]
stress_prob = [d.stress_probability for d in stress_report.daily_stats]
colors = ["red" if p > 0.7 else "orange" if p > 0.4 else "green" for p in stress_prob]
ax.bar(dates, [p * 100 for p in stress_prob], color=colors, alpha=0.7)
ax.axhline(70, color="red", ls="--", alpha=0.5, label=">70%: irrigate")
ax.axhline(40, color="orange", ls="--", alpha=0.5, label="40-70%: consider")
ax.set_ylabel("Stress probability (%)")
ax.set_title("Probability of crop stress (Ks < 0.9)")
ax.legend()

# Precipitation
ax = axes[2]
precip_mean = [d.precip_mean for d in stress_report.daily_stats]
ax.bar(dates, precip_mean, color="steelblue", alpha=0.7, label="mean precip")
ax.set_ylabel("mm/day")
ax.set_title("Forecast precipitation")
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Block 5b — Seasonal Outlook (SEAS5, optional)
#
# PCA analog matching → daily disaggregation → ensemble water balance.
# Set `RUN_SEAS5 = True` at the top to enable.

# %%
outlook = None

if RUN_SEAS5:
    from irrigator.ingestion.cds_client import fetch_seas5, open_seas5
    from irrigator.forecasts.seas5_processor import (
        build_era5_monthly_climatology,
        correct_seas5_monthly,
    )
    from irrigator.forecasts.disaggregation import generate_seasonal_scenarios
    from irrigator.decision.seasonal_outlook import compute_seasonal_outlook

    init_year = TODAY.year
    init_month = TODAY.month

    # Fetch + bias correct SEAS5
    fetch_seas5(year=init_year, month=init_month, raw_dir=RAW_DIR)
    seas5_anom = open_seas5(raw_dir=RAW_DIR, year=init_year, month=init_month)
    era5_clim = build_era5_monthly_climatology(
        start_year=1993, end_year=2016, processed_dir=PROCESSED_DIR,
    )
    seas5_corrected = correct_seas5_monthly(seas5_anom, era5_clim, init_month=init_month)

    # Analog disaggregation (PCA + Mahalanobis + spatial voting)
    scenarios = generate_seasonal_scenarios(
        cfg=cfg,
        era5_daily=era5_daily,
        seas5_corrected=seas5_corrected,
        init_month=init_month,
        n_leads=4,
    )

    # Run water balance under each scenario
    outlook = compute_seasonal_outlook(
        scenarios=scenarios,
        parcel=parcel,
        terrain=terrain,
        soil=soil,
        crop_params=crop_params,
    )

    print(f"\nSeasonal outlook ({outlook.n_members} members):")
    print(f"  Irrigation needed: {outlook.total_irrigation_p25:.0f}–{outlook.total_irrigation_p75:.0f} mm (p25–p75)")
    print(f"  Median: {outlook.total_irrigation_median:.0f} mm")
    print(f"  Stress days: median {outlook.stress_days_median:.0f}")
    print(f"  {outlook.season_description}")
else:
    print("SEAS5 seasonal outlook skipped (set RUN_SEAS5=True to enable)")
# Out:
# SEAS5 seasonal outlook skipped (set RUN_SEAS5=True to enable)

# %% [markdown]
# ---
# ## Block 6 — Irrigation Decision
#
# Uses current_state (from AquaCrop) + stress_report (blended AROME + IFS ENS)
# to produce an actionable recommendation. The decision logic is unchanged —
# it works with the EnsembleStressReport format regardless of whether the
# underlying model is FAO-56 bucket or AquaCrop.

# %%
from irrigator.decision.rules import compute_recommendation, DecisionParams
from irrigator.decision.output import build_parcel_report, save_report, format_sms
from irrigator.crop.phenology import CropParams

crop_params = CropParams.from_config(parcel.crop, crop_params_path=CROP_PARAMS_PATH)

params = DecisionParams.from_config(
    model_params_path=MODEL_PARAMS_PATH,
    parcel=parcel,
)

advice = compute_recommendation(
    current_state=current_state,
    stress_report=stress_report,
    crop_params=crop_params,
    params=params,
    last_irrigation_date=LAST_IRRIGATION,
)

print(f"\n{'=' * 60}")
print(f"IRRIGATION RECOMMENDATION for {parcel.name}")
print(f"{'=' * 60}")
action = "Irrigate" if advice.irrigate else "No need to irrigate"
print(f"  Action:     {action}")
if advice.dose_mm:
    print(f"  Amount:     {advice.dose_mm:.0f} mm")
print(f"  Confidence: {advice.confidence}")
print(f"  Reason:     {advice.reason}")
print(f"  Stage:      {advice.crop_stage}")
if advice.stress_probability is not None:
    print(f"  Stress probability: {advice.stress_probability:.0%}")
print(f"{'=' * 60}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 5
#       2 from irrigator.decision.output import build_parcel_report, save_report, format_sms
#       3 from irrigator.crop.phenology import CropParams
# ----> 5 crop_params = CropParams.from_config(parcel.crop, crop_params_path=CROP_PARAMS_PATH)
#       7 params = DecisionParams.from_config(
#       8     model_params_path=MODEL_PARAMS_PATH,
#       9     parcel=parcel,
#      10 )
#      12 advice = compute_recommendation(
#      13     current_state=current_state,
#      14     stress_report=stress_report,
#    (...)
#      17     last_irrigation_date=LAST_IRRIGATION,
#      18 )
#
# File ~/code/IrriGator/src/irrigator/crop/phenology.py:101, in CropParams.from_config(cls, parcel_crop, crop_params_path)
#      98     crop_cfg = yaml.safe_load(f)["grain_maize"]
#     100 maturity_group = parcel_crop.get("maturity_group", "C1")
# --> 101 gdd_thresholds = crop_cfg["gdd_by_maturity_group"][maturity_group]
#     103 planting_str = parcel_crop["planting_date"]
#     104 if isinstance(planting_str, str):
#
# KeyError: 'G3'

# %%
# Build and save JSON report
print(f"\nSMS: {format_sms(advice)}")
# Out:
# SMS: [IrriGator] 2026-06-23: IRRIGUER 63mm le 2026-06-23. Réserve sol: 59%. Stade: midseason.

# %% [markdown]
# ---
# ## Block 6b — Ensemble Irrigation Optimizer
#
# Instead of simple threshold rules, tests candidate irrigation actions
# against each IFS ENS member and picks the best action by ensemble consensus.
#
# Tests: no irrigation, plus each (day, dose) combination:
# - Days: 0, 1, 2, ..., 7 days from today
# - Doses: min (15mm), mid (27mm), max (40mm) from parcel config
#
# For 25 candidates × 50 members = ~1250 AquaCrop runs (~5-8 minutes).

# %%
# --- Cell: Run optimizer ---

from irrigator.water_balance.aquacrop_adapter import (
    evaluate_candidates_ensemble,
    recommend_from_optimizer,
    build_candidates,
    evaluate_candidates_ensemble_branching_2level
)

# Build candidate actions from parcel constraints
candidates = build_candidates(parcel, max_days_ahead=10, max_events=2)
print(f"Testing {len(candidates)} candidates × {len(member_forcings)} members")
print(f"Candidates: {[c.label for c in candidates[:5]]}...")

# Evaluate each candidate against the ensemble
# This is the expensive step (~5-8 minutes)

optimizer_results = evaluate_candidates_ensemble_branching_2level(
    historical_forcing=historical_forcing,
    arome_forcing=arome_forcing_48h,
    member_forcings=member_forcings,
    parcel=parcel,
    terrain=terrain,
    soil_profile=soil,
    sim_start=SIMULATION_START,
    today=TODAY,
    candidates=candidates,
    workers=10,
    stress_threshold=0.9,
    arome_days=2,
)
# Out:
# 16:42:21 [irrigator.water_balance.aquacrop_adapter] INFO: Built 54 candidates (1-event: 33, 2-event: 20, 3-event: 0)
# 16:42:21 [irrigator.water_balance.aquacrop_adapter] INFO: AquaCrop soil: 2.30m depth, 23 x 0.10m compartments, FC range 0.319-0.352, WP range 0.179-0.216, Ksat range 1-581 mm/day
# Testing 54 candidates × 50 members
# Candidates: ['No irrigation', '15mm on day+0', '32mm on day+0', '50mm on day+0', '15mm on day+1']...
# MaizeGDD
# 16:42:23 [irrigator.water_balance.aquacrop_adapter] INFO: Evaluating 54 candidates × 50 members = 2700 AquaCrop branches (two-level branching, arome_days=2, workers=10)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# /home/mbaldacchino/code/IrriGator/src/irrigator/water_balance/aquacrop_adapter.py:1991: RuntimeWarning: invalid value encountered in divide
#   ks = np.where(tr_pot > 0.01, tr / tr_pot, 1.0)
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 1/54 'No irrigation': mean_stress=0.580, avoid_pct=0%, mean_stress_days=8.8
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 2/54 '15mm on day+0': mean_stress=0.525, avoid_pct=0%, mean_stress_days=10.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 3/54 '32mm on day+0': mean_stress=0.406, avoid_pct=0%, mean_stress_days=7.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 4/54 '50mm on day+0': mean_stress=0.245, avoid_pct=0%, mean_stress_days=6.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 5/54 '15mm on day+1': mean_stress=0.509, avoid_pct=0%, mean_stress_days=9.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 6/54 '32mm on day+1': mean_stress=0.379, avoid_pct=0%, mean_stress_days=6.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 7/54 '50mm on day+1': mean_stress=0.207, avoid_pct=4%, mean_stress_days=4.5
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 8/54 '15mm on day+2': mean_stress=0.569, avoid_pct=0%, mean_stress_days=9.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 9/54 '32mm on day+2': mean_stress=0.569, avoid_pct=0%, mean_stress_days=6.5
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 10/54 '50mm on day+2': mean_stress=0.569, avoid_pct=0%, mean_stress_days=3.6
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 11/54 '15mm on day+3': mean_stress=0.570, avoid_pct=0%, mean_stress_days=8.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 12/54 '32mm on day+3': mean_stress=0.570, avoid_pct=0%, mean_stress_days=6.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 13/54 '50mm on day+3': mean_stress=0.570, avoid_pct=0%, mean_stress_days=3.6
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 14/54 '15mm on day+4': mean_stress=0.571, avoid_pct=0%, mean_stress_days=8.8
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 15/54 '32mm on day+4': mean_stress=0.571, avoid_pct=0%, mean_stress_days=5.5
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 16/54 '50mm on day+4': mean_stress=0.571, avoid_pct=0%, mean_stress_days=4.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 17/54 '15mm on day+5': mean_stress=0.578, avoid_pct=0%, mean_stress_days=7.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 18/54 '32mm on day+5': mean_stress=0.578, avoid_pct=0%, mean_stress_days=5.4
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 19/54 '50mm on day+5': mean_stress=0.578, avoid_pct=0%, mean_stress_days=4.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 20/54 '15mm on day+6': mean_stress=0.580, avoid_pct=0%, mean_stress_days=7.4
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 21/54 '32mm on day+6': mean_stress=0.580, avoid_pct=0%, mean_stress_days=5.6
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 22/54 '50mm on day+6': mean_stress=0.580, avoid_pct=0%, mean_stress_days=5.2
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 23/54 '15mm on day+7': mean_stress=0.580, avoid_pct=0%, mean_stress_days=7.4
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 24/54 '32mm on day+7': mean_stress=0.580, avoid_pct=0%, mean_stress_days=6.2
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 25/54 '50mm on day+7': mean_stress=0.580, avoid_pct=0%, mean_stress_days=6.1
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 26/54 '15mm on day+8': mean_stress=0.580, avoid_pct=0%, mean_stress_days=7.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 27/54 '32mm on day+8': mean_stress=0.580, avoid_pct=0%, mean_stress_days=6.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 28/54 '50mm on day+8': mean_stress=0.580, avoid_pct=0%, mean_stress_days=6.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 29/54 '15mm on day+9': mean_stress=0.580, avoid_pct=0%, mean_stress_days=8.5
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 30/54 '32mm on day+9': mean_stress=0.580, avoid_pct=0%, mean_stress_days=7.7
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 31/54 '50mm on day+9': mean_stress=0.580, avoid_pct=0%, mean_stress_days=7.7
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 32/54 '15mm on day+10': mean_stress=0.580, avoid_pct=0%, mean_stress_days=8.2
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 33/54 '32mm on day+10': mean_stress=0.580, avoid_pct=0%, mean_stress_days=8.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 34/54 '50mm on day+10': mean_stress=0.580, avoid_pct=0%, mean_stress_days=8.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 35/54 '2×15mm on day+0 & +7': mean_stress=0.524, avoid_pct=0%, mean_stress_days=7.0
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 36/54 '2×50mm on day+0 & +7': mean_stress=0.203, avoid_pct=0%, mean_stress_days=2.7
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 37/54 '2×15mm on day+0 & +8': mean_stress=0.524, avoid_pct=0%, mean_stress_days=7.2
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 38/54 '2×50mm on day+0 & +8': mean_stress=0.209, avoid_pct=0%, mean_stress_days=3.4
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 39/54 '2×15mm on day+0 & +9': mean_stress=0.524, avoid_pct=0%, mean_stress_days=7.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 40/54 '2×50mm on day+0 & +9': mean_stress=0.214, avoid_pct=0%, mean_stress_days=3.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 41/54 '2×15mm on day+0 & +10': mean_stress=0.525, avoid_pct=0%, mean_stress_days=7.7
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 42/54 '2×50mm on day+0 & +10': mean_stress=0.220, avoid_pct=0%, mean_stress_days=4.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 43/54 '2×15mm on day+1 & +8': mean_stress=0.507, avoid_pct=0%, mean_stress_days=6.2
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 44/54 '2×50mm on day+1 & +8': mean_stress=0.165, avoid_pct=8%, mean_stress_days=2.1
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 45/54 '2×15mm on day+1 & +9': mean_stress=0.507, avoid_pct=0%, mean_stress_days=6.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 46/54 '2×50mm on day+1 & +9': mean_stress=0.171, avoid_pct=8%, mean_stress_days=2.5
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 47/54 '2×15mm on day+1 & +10': mean_stress=0.508, avoid_pct=0%, mean_stress_days=6.8
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 48/54 '2×50mm on day+1 & +10': mean_stress=0.179, avoid_pct=8%, mean_stress_days=2.9
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 49/54 '2×15mm on day+2 & +9': mean_stress=0.569, avoid_pct=0%, mean_stress_days=6.3
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 50/54 '2×50mm on day+2 & +9': mean_stress=0.569, avoid_pct=0%, mean_stress_days=2.1
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 51/54 '2×15mm on day+2 & +10': mean_stress=0.569, avoid_pct=0%, mean_stress_days=6.7
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 52/54 '2×50mm on day+2 & +10': mean_stress=0.569, avoid_pct=0%, mean_stress_days=2.4
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 53/54 '2×15mm on day+3 & +10': mean_stress=0.570, avoid_pct=0%, mean_stress_days=6.6
# 16:42:39 [irrigator.water_balance.aquacrop_adapter] INFO: Candidate 54/54 '2×50mm on day+3 & +10': mean_stress=0.570, avoid_pct=0%, mean_stress_days=2.7

# %%
from aquacrop import AquaCropModel

# %%
# --- Cell: Optimizer recommendation ---

recommendation = recommend_from_optimizer(optimizer_results, top_x=3)

print(f"\n{'=' * 60}")
print(f"OPTIMIZED IRRIGATION RECOMMENDATION")
print(f"{'=' * 60}")
print(f"  Action:     {recommendation[0]['action']}")
print(f"  Reason:     {recommendation[0]['reason']}")
print(f"  Avoid stress: {recommendation[0]['avoid_stress_pct']:.0%} of members")
print(f"  Mean stress days: {recommendation[0]['mean_stress_days']:.1f}")
if "cost_eur_ha" in recommendation[0]:
    print(f"  Water cost: €{recommendation[0]['cost_eur_ha']:.0f}/ha")
print(f"{'=' * 60}")


print(f"\n{'=' * 60}")
print(f"ALTERNATIVES")
print(f"{'=' * 60}")
print(f"  Action:     {recommendation[1]['action']}")
print(f"  Reason:     {recommendation[1]['reason']}")
print(f"  Avoid stress: {recommendation[1]['avoid_stress_pct']:.0%} of members")
print(f"  Mean stress days: {recommendation[1]['mean_stress_days']:.1f}")
if "cost_eur_ha" in recommendation[1]:
    print(f"  Water cost: €{recommendation[1]['cost_eur_ha']:.0f}/ha")
print(f"{'=' * 60}")
print(f"{'=' * 60}")
print(f"  Action:     {recommendation[2]['action']}")
print(f"  Reason:     {recommendation[2]['reason']}")
print(f"  Avoid stress: {recommendation[2]['avoid_stress_pct']:.0%} of members")
print(f"  Mean stress days: {recommendation[2]['mean_stress_days']:.1f}")
if "cost_eur_ha" in recommendation[2]:
    print(f"  Water cost: €{recommendation[2]['cost_eur_ha']:.0f}/ha")
print(f"{'=' * 60}")
# Out:
# ============================================================
# OPTIMIZED IRRIGATION RECOMMENDATION
# ============================================================
#   Action:     2×50mm on day+1 & +8 (limited benefit)
#   Reason:     No action avoids stress in >70% of members. Best option: 8% avoid stress, mean 2.1 stress days
#   Avoid stress: 8% of members
#   Mean stress days: 2.1
# ============================================================
#
# ============================================================
# ALTERNATIVES
# ============================================================
#   Action:     2×50mm on day+1 & +9 (limited benefit)
#   Reason:     No action avoids stress in >70% of members. Best option: 8% avoid stress, mean 2.5 stress days
#   Avoid stress: 8% of members
#   Mean stress days: 2.5
# ============================================================
# ============================================================
#   Action:     2×50mm on day+1 & +10 (limited benefit)
#   Reason:     No action avoids stress in >70% of members. Best option: 8% avoid stress, mean 2.9 stress days
#   Avoid stress: 8% of members
#   Mean stress days: 2.9
# ============================================================

# %%
recommendation
# Out:
# [{'action': '2×50mm on day+1 & +8 (limited benefit)',
#   'reason': 'No action avoids stress in >70% of members. Best option: 8% avoid stress, mean 2.1 stress days',
#   'candidate': IrrigationCandidate(events=[(1, 50), (8, 50)], label='2×50mm on day+1 & +8'),
#   'avoid_stress_pct': 0.08,
#   'mean_stress_days': 2.1,
#   'all_results': [CandidateResult(candidate=IrrigationCandidate(events=[(1, 50), (8, 50)], label='2×50mm on day+1 & +8'), member_max_stress=[0.16916131932095035, 0.146010112232125, 0.14249559557072788, 0.17922687469632914, 0.16369452746282032, 0.14790974655290878, 0.19503354732920797, 0.08729662458099874, 0.16696304678759322, 0.16990571670216137, 0.1316383453023825, 0.12478647061995385, 0.1763678294029848, 0.1728679115123355, 0.20540667769959775, 0.15173122600863875, 0.22918337438377767, 0.14597789152239582, 0.23120333184262354, 0.15814927902445164, 0.17778778930119687, 0.2201485356764472, 0.16505704416747358, 0.18700839860433038, 0.17712922182048063, 0.17724705016207332, 0.2238707070515441, 0.17228578561599817, 0.18039438563061994, 0.1613232450572668, 0.1685977953340363, 0.1594749961648927, 0.2172903638557777, 0.2198712566067338, 0.13218739738945684, 0.1875509262855194, 0.1474840485547163, 0.1572950439279307, 0.16097473930186068, 0.22617651669540584, 0.20801942266545248, 0.024969049671437538, 0.17380438677385845, 0.14545990807590647, 0.19967746827865074, 0.1682181450542406, 0.008048588493280606, 0.15833120757668506, 0.07924984731611506, 0.17803717582032508], member_stress_days=[1, 1, 1, 1, 3, 1, 3, 0, 1, 3, 2, 2, 3, 3, 3, 1, 3, 1, 2, 3, 3, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 1, 3, 3, 3,
matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Top 10 candidates by avoid_stress_pct
top10 = optimizer_results[:10]

labels = [r.candidate.label for r in top10]
avoid_pct = [r.pct_members_avoid_stress * 100 for r in top10]
mean_stress = [r.mean_stress_days for r in top10]

ax = axes[0]
colors = ["green" if p > 70 else "orange" if p > 40 else "red" for p in avoid_pct]
bars = ax.barh(range(len(top10)), avoid_pct, color=colors, alpha=0.7)
ax.set_yticks(range(len(top10)))
ax.set_yticklabels(labels)
ax.axvline(70, color="red", ls="--", alpha=0.5, label="70% threshold")
ax.set_xlabel("% of ensemble members avoiding stress")
ax.set_title("Top 10 irrigation strategies — ensemble evaluation")
ax.legend()
ax.invert_yaxis()

ax = axes[1]
ax.barh(range(len(top10)), mean_stress, color="steelblue", alpha=0.7)
ax.set_yticks(range(len(top10)))
ax.set_yticklabels(labels)
ax.set_xlabel("Mean stress days over forecast horizon")
ax.set_title("Expected stress days per strategy")
ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# --- Cell: Detailed comparison table ---

print(f"\n{'Label':<25} {'Avoid %':>8} {'Stress days':>12} {'Mean stress':>12}")
print("-" * 60)
for r in optimizer_results[:15]:
    print(
        f"{r.candidate.label:<25} {r.pct_members_avoid_stress:>7.0%} "
        f"{r.mean_stress_days:>11.1f} {r.mean_max_stress:>11.3f}"
    )
# Out:
# Label                      Avoid %  Stress days  Mean stress
# ------------------------------------------------------------
# 2×50mm on day+1 & +5         100%         0.0       0.000
# 2×50mm on day+1 & +4         100%         0.0       0.000
# 2×50mm on day+0 & +3         100%         0.0       0.000
# 2×50mm on day+0 & +4         100%         0.0       0.000
# 2×50mm on day+0 & +5         100%         0.0       0.007
# 2×50mm on day+1 & +6         100%         0.0       0.008
# 2×50mm on day+0 & +6          96%         0.0       0.043
# 2×50mm on day+1 & +7          80%         0.2       0.067
# 2×50mm on day+0 & +7          64%         0.4       0.089
# 2×50mm on day+1 & +8          52%         0.7       0.105
# 2×50mm on day+0 & +8          30%         1.1       0.125
# 2×50mm on day+1 & +9          24%         1.4       0.148
# 2×50mm on day+1 & +10         20%         2.2       0.175
# 2×50mm on day+1 & +11         16%         2.9       0.197
# 2×50mm on day+0 & +9          12%         1.9       0.160

# %% [markdown]
# ---
# ## Summary: data flow
#
# ```
# ERA5-Land France-wide cache ──[Block 2: extract + downscale]──→ DailyForcing (parcel)
#                                                                        │
#                                                       [Blocks 3+4: simulation]──→ current_state
#                                                                                         │
# AROME France-wide cache ──[extract + downscale]──→ DailyForcing (parcel)                │
#                                                          │                              │
# IFS ENS download ──[process daily]──[extract]──→ 51× DailyForcing (parcel)              │
#                                                          │                              │
#                                               [Block 5a: ensemble forward balance]──────┤
#                                                                                         │
# SEAS5 ──[bias correct]──[PCA analog]──[extract]──→ N× DailyForcing                     │
#                                                          │                              │
#                                               [Block 5b: seasonal water balance]────────┤
#                                                                                         │
#                                               [Block 6: decision rules]─────→ IrrigationAdvice
# ```
#
# All gridded data sources (ERA5-Land, AROME, IFS ENS, SEAS5 analogs) are France-wide.
# Parcel extraction happens once through `extract_parcel_forcing()` — one function,
# one set of corrections (lapse rate, radiation, wind), for all sources.
