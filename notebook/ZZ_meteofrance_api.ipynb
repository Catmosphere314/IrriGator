# %% [markdown]
# # Generate the Client Authetificators

# %% [markdown]
# To get the AUTH value:
# 1 - Log in to the Météo-France API portal \
# 2 - Go to Mes API \
# 3 - Select the API you want to use \
# 4 - Click Générer Token \
# 5 - Look at the generated curl command \
# 6 - Copy the value after **Authorization : Basic**

# %%
from irrigator.utils.auth_meteofrance import meteo_headers

headers = meteo_headers()

# %% [markdown]
# # Generate the 1-hour API token

# %%
from irrigator.utils.auth_meteofrance import get_meteofrance_access_token
import os
os.environ["METEOFRANCE_API_KEY"] = get_meteofrance_access_token()

# %% [markdown]
# # Run a request
